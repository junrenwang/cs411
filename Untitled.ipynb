# %%
from csv import DictReader

for row in DictReader(open('./charity_data.csv')):
            category_names = row['category']
            categ_names = [name.strip() for name in category_names.split('|') if name]
            print(categ_names)
# Out:
# ['Human Services', 'Education']
# ['Arts, Culture, Humanities']
# ['Health']
# ['Human Services']
# ['Arts, Culture, Humanities']
# ['Human and Civil Rights']
# ['Education']
# ['International']
# ['Religion']
# ['International']
# ['Environment']
# ['Religion']
# ['Human Services']
# ['Health']
# ['Health']
# ['Health']
# ['Health']
# ['Health']
# ['Animals']
# ['Animals']
# ['Health']
# ['Animals']
# ['Human and Civil Rights']
# ['Religion']
# ['Community Development']
# ['Health']
# ['Human and Civil Rights']
# ['Human Services']
# ['Education']
# ['Human Services']
# ['Human Services']
# ['Health']
# ['Human Services']
# ['Human Services', 'Human and Civil Rights']
# ['Religion', 'Human Services']
# ['Health']
# ['Community Development']
# ['Human Services']
# ['Human and Civil Rights']
# ['Health']
# ['Religion']
# ['Health']
# ['Human Services']
# ['Human and Civil Rights']
# ['Human Services']
# ['Environment']
# ['Human and Civil Rights']
# ['Human Services']
# ['Animals']
# ['Health']
# ['Arts, Culture, Humanities']
# ['Education']
# ['Human and Civil Rights']
# ['Environment']
# ['Community Development']
# ['Education']
# ['Arts, Culture, Humanities']
# ['Human Services']
# ['Human and Civil Rights']
# ['Environment']
# ['Arts, Culture, Humanities']
# ['Education']
# ['Arts, Culture, Humanities']
# ['Human and Civil Rights']
# ['Human and Civil Rights']
# ['Human Services']
# ['Human Services']
# ['Arts, Culture, Humanities']
# ['Arts, Culture, Humanities']
# ['Education']
# ['Arts, Culture, Humanities']
# ['Arts, Culture, Humanities']
# ['Human and Civil Rights']
# ['Human Services']
# ['Human Services']
# ['Animals']
# ['Health']
# ['International']
# ['Health']
# ['Research and Public Policy']
# ['Education']
# ['Education']
# ['Education']
# ['Human Services']
# ['Human Services']
# ['Health']
# ['Education']
# ['Human Services']
# ['Health']
# ['Health']
# ['Arts, Culture, Humanities']
# ['Health']
# ['Human Services']
# ['Health']
# ['Human Services']
# ['Community Development']
# ['Environment']
# ['Education']
# ['Education']
# ['Education']
